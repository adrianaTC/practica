# %% [markdown]
# <a href="https://colab.research.google.com/github/adrianaTC/practica/blob/main/Tipo_instrumento_java.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# %%writefile Instrumento.java
# public class Instrumento {
#     private String ID;
#     private double precio;
#     private Tipoinstrumento tipo;
# }
# Out:
# Writing Instrumento.java
